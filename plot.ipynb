# %%
import pandas as pd

annoy = pd.read_csv('results/annoy-mnist.csv', index_col=0)
annoy['method'] = 'annoy'
annoy.head()
# Out:
#    query_time   recall method
# 0    0.000555  0.38502  annoy
# 1    0.001049  0.75086  annoy
# 2    0.002017  0.91931  annoy
# 3    0.002560  0.95536  annoy
# 4    0.002988  0.96946  annoy

# %%
annoy.plot(x="recall", y="query_time")
# Out:
# <Axes: xlabel='recall'>

# %%
LSH = pd.read_csv('results/lsh-mnist.csv', index_col=0)
LSH['method'] = "LSH"

PQ = pd.read_csv('results/pq-mnist.csv', index_col=0)
PQ['method'] = "PQ"

HNSW = pd.read_csv('results/HNSW-mnist.csv', index_col=0)
HNSW['method'] = "HNSW"

df = pd.concat([annoy, LSH, PQ, HNSW])
df.head(n=10)
# Out:
#    query_time   recall method
# 0    0.000555  0.38502  annoy
# 1    0.001049  0.75086  annoy
# 2    0.002017  0.91931  annoy
# 3    0.002560  0.95536  annoy
# 4    0.002988  0.96946  annoy
# 5    0.003398  0.97647  annoy
# 6    0.003797  0.98068  annoy
# 7    0.004115  0.98427  annoy
# 0    0.000231  0.37113    LSH
# 1    0.000354  0.49183    LSH

# %%
import seaborn as sns

sns.lineplot(data=df, x='recall', y='query_time', hue='method')
# Out:
# <Axes: xlabel='recall', ylabel='query_time'>
