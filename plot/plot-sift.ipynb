# %%
import pandas as pd

annoy = pd.read_csv('results/annoy-sift.csv', index_col=0)
annoy['method'] = 'annoy'
annoy.head()
# Out:
#    query_time   recall          QPS  build_time method
# 0    0.000317  0.45655  3155.735627   14.510295  annoy
# 1    0.000552  0.61212  1810.893240   21.623196  annoy
# 2    0.000777  0.69938  1287.585311   26.165119  annoy
# 3    0.001060  0.76528   943.806622   34.080692  annoy
# 4    0.001222  0.79677   818.044512   47.047127  annoy

# %%
annoy.plot(x="recall", y="QPS")
# Out:
# <Axes: xlabel='recall'>

# %%
LSH = pd.read_csv('results/lsh-sift.csv', index_col=0)
LSH['method'] = "LSH"

PQ = pd.read_csv('results/pq-sift.csv', index_col=0)
PQ['method'] = "PQ"

HNSW = pd.read_csv('results/HNSW-sift.csv', index_col=0)
HNSW['method'] = "HNSW"

df = pd.concat([annoy, LSH, PQ, HNSW])
df.head(n=10)
# Out:
#    query_time   recall          QPS  build_time method
# 0    0.000317  0.45655  3155.735627   14.510295  annoy
# 1    0.000552  0.61212  1810.893240   21.623196  annoy
# 2    0.000777  0.69938  1287.585311   26.165119  annoy
# 3    0.001060  0.76528   943.806622   34.080692  annoy
# 4    0.001222  0.79677   818.044512   47.047127  annoy
# 5    0.001303  0.83419   767.561969   46.798479  annoy
# 6    0.001440  0.84514   694.598752   53.063609  annoy
# 7    0.001574  0.87098   635.144252   58.751323  annoy
# 8    0.001726  0.88635   579.328558   65.980875  annoy
# 9    0.001890  0.89589   529.093892   74.461362  annoy

# %%
import seaborn as sns

sns.lineplot(data=df, x='recall', y='QPS', hue='method')
# Out:
# <Axes: xlabel='recall', ylabel='QPS'>

# %%
sns.lineplot(data=df, x='recall', y='build_time', hue='method')
# Out:
# <Axes: xlabel='recall', ylabel='build_time'>
